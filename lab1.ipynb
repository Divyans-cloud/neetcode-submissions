# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyans-cloud/neetcode-submissions/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def step(x):
  return np.where(x<0,0,1)

# %%
def sigmoid(x):
  x=np.array(x)
  return 1/(1+np.exp(-x))

# %%
sigmoid([1,3,4,3,-9])
# Out:
# array([7.31058579e-01, 9.52574127e-01, 9.82013790e-01, 9.52574127e-01,
#        1.23394576e-04])

# %%
sigmoid(0)
# Out:
# np.float64(0.5)

# %%
def percentage_close(weather_score):
  weather_score=np.array(weather_score)
  return 100* sigmoid(weather_score)

# %%
def relu(x):
  """ ReLU activation function
  Returns max(0,x).
  must work with the numpy arrays. """
  x=np.array(x)
  return np.where(x<0,0,x)
  print(result)

# %%
relu([1,3,4,3,-9])
# Out:
# array([1, 3, 4, 3, 0])
